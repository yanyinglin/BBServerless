# %%
import os,time
import subprocess
path_ml = '/home/pengshijie/bbserverlees/DIC/MachineLearning/Inference-of-ml-openfaas/'
path_bigdata= '/home/pengshijie/bbserverlees/DIC/BigData/openfaas/'
path_stream='/home/pengshijie/bbserverlees/DIC/Stream/openfaas/'
path_web='/home/pengshijie/bbserverlees/DIC/WebServices/openfaas/python-code/'

# %%
def update_openfaas(path):
    os.chdir(path)
    current_path = os.getcwd()
    print(current_path)
    print(subprocess.getoutput('faas-cli template pull'))
    build = 'action_build.sh'
    r = os.popen('bash '+build).read()
    print(r)
    push = 'action_push.sh'
    r = os.popen('bash '+push).read()
    print(r)
    deploy = 'action_deploy.sh'
    r = os.popen('bash '+deploy).read()
    print(r)

# %%
update_openfaas(path_ml)
# Out:
# /home/pengshijie/bbserverlees/DIC/MachineLearning/Inference-of-ml-openfaas
# Fetch templates from repository: https://github.com/openfaas/templates.git at
# 2023/08/17 11:16:14 Attempting to expand templates from https://github.com/openfaas/templates.git
# 2023/08/17 11:16:17 Cannot overwrite the following 16 template(s): [csharp dockerfile go java11 java11-vert-x node node14 node16 node17 node18 php7 php8 python python3 python3-debian ruby]
# 2023/08/17 11:16:17 Fetched 0 template(s) : [] from https://github.com/openfaas/templates.git
# [0] > Building sgdclassifier-general.
# Clearing temporary build folder: ./build/sgdclassifier-general/
# Preparing: ./sgdclassifier-general/ build/sgdclassifier-general/function
# Building: k.harbor.siat.ac.cn/openfaas/sgdclassifier-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  2.978MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Running in d8e7ba50c62f
# Removing intermediate container d8e7ba50c62f
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Running in 9823bc33fa4f
# Get:1 http://deb.debian.org/debian bookworm InRelease [151 kB]
# Get:2 http://deb.debian.org/debian bookworm-updates InRelease [52.1 kB]
# Get:3 http://deb.debian.org/debian-security bookworm-security InRelease [48.0 kB]
# Get:4 http://deb.debian.org/debian bookworm/main amd64 Packages [8906 kB]
# Get:5 http://deb.debian.org/debian bookworm-updates/main amd64 Packages [4732 B]
# Get:6 http://deb.debian.org/debian-security bookworm-security/main amd64 Packages [57.2 kB]
# Fetched 9219 kB in 7s (1291 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ca-certificates is already the newest version (20230311).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Removing intermediate container 9823bc33fa4f
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Running in fad052ef6932
# Removing intermediate container fad052ef6932
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Running in 1aef5371df08
# Removing intermediate container 1aef5371df08
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Running in e5e10543199c
# Removing intermediate container e5e10543199c
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Running in 4dc9e5fec0cb
# Removing intermediate container 4dc9e5fec0cb
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Running in ba5ada79a9b5
# Removing intermediate container ba5ada79a9b5
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Running in 54ccfd2f255d
# Removing intermediate container 54ccfd2f255d
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Running in f4fbf8ea7740
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Removing intermediate container f4fbf8ea7740
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Running in 3c35f5ef2ad1
# Removing intermediate container 3c35f5ef2ad1
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Running in d8778af7d333
# Removing intermediate container d8778af7d333
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Running in b2d5c1794a5d
# Removing intermediate container b2d5c1794a5d
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Running in 1c75e1138fb6
# Collecting numpy==1.25.2 (from -r requirements.txt (line 1))
#   Downloading numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 1.8 MB/s eta 0:00:00
# Collecting scikit_learn==1.3.0 (from -r requirements.txt (line 2))
#   Downloading scikit_learn-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 2.0 MB/s eta 0:00:00
# Collecting scipy>=1.5.0 (from scikit_learn==1.3.0->-r requirements.txt (line 2))
#   Downloading scipy-1.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 1.6 MB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit_learn==1.3.0->-r requirements.txt (line 2))
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 1.6 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit_learn==1.3.0->-r requirements.txt (line 2))
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit_learn
# Successfully installed joblib-1.3.2 numpy-1.25.2 scikit_learn-1.3.0 scipy-1.11.1 threadpoolctl-3.2.0
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Collecting Pillow
#   Downloading Pillow-10.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: Pillow
# Successfully installed Pillow-10.0.0
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Removing intermediate container 1c75e1138fb6
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Running in aa7e83eacd08
# Removing intermediate container aa7e83eacd08
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Running in 5530af7e02c7
# Removing intermediate container 5530af7e02c7
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> 558a71de415c
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 1c25c5b12b07
# Removing intermediate container 1c25c5b12b07
#  ---> f924c98f9270
# Step 28/32 : USER app
#  ---> Running in f407e018f56b
# Removing intermediate container f407e018f56b
#  ---> c6bcd58ed3d4
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 2238e8630f65
# Removing intermediate container 2238e8630f65
#  ---> 5f976876ca3a
# Step 30/32 : EXPOSE 8080
#  ---> Running in dceff7cfaad4
# Removing intermediate container dceff7cfaad4
#  ---> d35cc6e1784f
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 18fd338fcdb2
# Removing intermediate container 18fd338fcdb2
#  ---> eedade16bafd
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in c18a32b7d56c
# Removing intermediate container c18a32b7d56c
#  ---> a7bd6bd11efe
# Successfully built a7bd6bd11efe
# Successfully tagged k.harbor.siat.ac.cn/openfaas/sgdclassifier-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/sgdclassifier-general:1.3 built.
# [0] < Building sgdclassifier-general done in 378.03s.
# [0] > Building randomforestregressor-general.
# Clearing temporary build folder: ./build/randomforestregressor-general/
# Preparing: ./randomforestregressor-general/ build/randomforestregressor-general/function
# Building: k.harbor.siat.ac.cn/openfaas/randomforestregressor-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  183.4MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> 2197a054fcff
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 52977856fd48
# Removing intermediate container 52977856fd48
#  ---> c54470ba2e4b
# Step 28/32 : USER app
#  ---> Running in 868d64d7d39f
# Removing intermediate container 868d64d7d39f
#  ---> 5d7ca0161bc5
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 2dce0d88eeda
# Removing intermediate container 2dce0d88eeda
#  ---> 734367799c06
# Step 30/32 : EXPOSE 8080
#  ---> Running in d339dcadbc1a
# Removing intermediate container d339dcadbc1a
#  ---> c0950f27a2f6
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in f6a6e7272881
# Removing intermediate container f6a6e7272881
#  ---> 9c0ab2dc2bb8
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 58d0b3f26514
# Removing intermediate container 58d0b3f26514
#  ---> 9b0bfd2090bd
# Successfully built 9b0bfd2090bd
# Successfully tagged k.harbor.siat.ac.cn/openfaas/randomforestregressor-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/randomforestregressor-general:1.3 built.
# [0] < Building randomforestregressor-general done in 174.52s.
# [0] > Building perceptron-general.
# Clearing temporary build folder: ./build/perceptron-general/
# Preparing: ./perceptron-general/ build/perceptron-general/function
# Building: k.harbor.siat.ac.cn/openfaas/perceptron-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  2.978MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> 4d6e118ebfaa
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 0f7fd45da947
# Removing intermediate container 0f7fd45da947
#  ---> e6ec0f2135c3
# Step 28/32 : USER app
#  ---> Running in 5ad2e70d9797
# Removing intermediate container 5ad2e70d9797
#  ---> b0e8f5c9f7ca
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 8a2306424c4b
# Removing intermediate container 8a2306424c4b
#  ---> d78329f47872
# Step 30/32 : EXPOSE 8080
#  ---> Running in a260130ece2d
# Removing intermediate container a260130ece2d
#  ---> bde2ff62902e
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 29ff4d60fb75
# Removing intermediate container 29ff4d60fb75
#  ---> 994174b23685
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 5ad9edc32c16
# Removing intermediate container 5ad9edc32c16
#  ---> 862176869a51
# Successfully built 862176869a51
# Successfully tagged k.harbor.siat.ac.cn/openfaas/perceptron-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/perceptron-general:1.3 built.
# [0] < Building perceptron-general done in 154.58s.
# [0] > Building multinomialnb-general.
# Clearing temporary build folder: ./build/multinomialnb-general/
# Preparing: ./multinomialnb-general/ build/multinomialnb-general/function
# Building: k.harbor.siat.ac.cn/openfaas/multinomialnb-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon   9.27MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> cc0257809b60
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 3b87e09217ad
# Removing intermediate container 3b87e09217ad
#  ---> e4d8233011ef
# Step 28/32 : USER app
#  ---> Running in 3257b77021a6
# Removing intermediate container 3257b77021a6
#  ---> cf14a6011b9e
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 1b5109280068
# Removing intermediate container 1b5109280068
#  ---> 661088e4f42b
# Step 30/32 : EXPOSE 8080
#  ---> Running in bb045572a396
# Removing intermediate container bb045572a396
#  ---> 98065d3eb446
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in eaf0eee9ac04
# Removing intermediate container eaf0eee9ac04
#  ---> 95f175ac6cb8
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in d84f23ea2895
# Removing intermediate container d84f23ea2895
#  ---> 26a7fccc592c
# Successfully built 26a7fccc592c
# Successfully tagged k.harbor.siat.ac.cn/openfaas/multinomialnb-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/multinomialnb-general:1.3 built.
# [0] < Building multinomialnb-general done in 169.53s.
# [0] > Building passiveaggressiveclassifier-general.
# Clearing temporary build folder: ./build/passiveaggressiveclassifier-general/
# Preparing: ./passiveaggressiveclassifier-general/ build/passiveaggressiveclassifier-general/function
# Building: k.harbor.siat.ac.cn/openfaas/passiveaggressiveclassifier-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  2.978MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> 8316cecb7430
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 7d9ac86d19cb
# Removing intermediate container 7d9ac86d19cb
#  ---> e672f4c6d65c
# Step 28/32 : USER app
#  ---> Running in 812b1f9cd07e
# Removing intermediate container 812b1f9cd07e
#  ---> 1519997198d6
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in cba6f71db92d
# Removing intermediate container cba6f71db92d
#  ---> 3df59918a421
# Step 30/32 : EXPOSE 8080
#  ---> Running in 187a24021f77
# Removing intermediate container 187a24021f77
#  ---> 9ec4f2904bf2
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 3fd9cfd776f9
# Removing intermediate container 3fd9cfd776f9
#  ---> 1575b2652658
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 4a7eea4b102c
# Removing intermediate container 4a7eea4b102c
#  ---> 23b8e2cef4a9
# Successfully built 23b8e2cef4a9
# Successfully tagged k.harbor.siat.ac.cn/openfaas/passiveaggressiveclassifier-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/passiveaggressiveclassifier-general:1.3 built.
# [0] < Building passiveaggressiveclassifier-general done in 163.54s.
# [0] > Building svr-general.
# Clearing temporary build folder: ./build/svr-general/
# Preparing: ./svr-general/ build/svr-general/function
# Building: k.harbor.siat.ac.cn/openfaas/svr-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  6.385MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> 84cd5b068e23
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 68bb6cefaa46
# Removing intermediate container 68bb6cefaa46
#  ---> a96ec28a8bf7
# Step 28/32 : USER app
#  ---> Running in feb020787acc
# Removing intermediate container feb020787acc
#  ---> 1589100b7b6e
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in ca76750b52ea
# Removing intermediate container ca76750b52ea
#  ---> 9861c3c7b7a3
# Step 30/32 : EXPOSE 8080
#  ---> Running in e1f7e13521f2
# Removing intermediate container e1f7e13521f2
#  ---> 98ca229b464e
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 824ed88e65b4
# Removing intermediate container 824ed88e65b4
#  ---> 3edeb06151d3
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 91ad47946dc9
# Removing intermediate container 91ad47946dc9
#  ---> a5482a40c95f
# Successfully built a5482a40c95f
# Successfully tagged k.harbor.siat.ac.cn/openfaas/svr-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/svr-general:1.3 built.
# [0] < Building svr-general done in 172.39s.
# [0] > Building sgdregressor-general.
# Clearing temporary build folder: ./build/sgdregressor-general/
# Preparing: ./sgdregressor-general/ build/sgdregressor-general/function
# Building: k.harbor.siat.ac.cn/openfaas/sgdregressor-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  1.293MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> f4fc5ee6e4b9
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in ef17d357ae00
# Removing intermediate container ef17d357ae00
#  ---> c64f2fbf9002
# Step 28/32 : USER app
#  ---> Running in d8cefa93c193
# Removing intermediate container d8cefa93c193
#  ---> 1ae2ad103d7d
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 0fd89db5ba2e
# Removing intermediate container 0fd89db5ba2e
#  ---> 259a477d4773
# Step 30/32 : EXPOSE 8080
#  ---> Running in be9a5e65406d
# Removing intermediate container be9a5e65406d
#  ---> 43646c7668d6
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 0faad87c13da
# Removing intermediate container 0faad87c13da
#  ---> 62e38fdc3164
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 4fae7e361b31
# Removing intermediate container 4fae7e361b31
#  ---> c73a31f3624d
# Successfully built c73a31f3624d
# Successfully tagged k.harbor.siat.ac.cn/openfaas/sgdregressor-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/sgdregressor-general:1.3 built.
# [0] < Building sgdregressor-general done in 165.03s.
# [0] > Building facerecognition-general.
# Clearing temporary build folder: ./build/facerecognition-general/
# Preparing: ./facerecognition-general/ build/facerecognition-general/function
# Building: k.harbor.siat.ac.cn/openfaas/facerecognition-general:1.3 with python3-debian template. Please wait..
# Sending build context to Docker daemon  1.723MB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.2 as watchdog
#  ---> c4c73a9dc018
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Using cache
#  ---> 64fb95da219d
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Using cache
#  ---> 3c6a9368cc8e
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Using cache
#  ---> f7304dc15f39
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 61ea23b18542
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Using cache
#  ---> 7f3eeb440005
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Using cache
#  ---> 50953a382384
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Using cache
#  ---> 20cc45055541
# Step 11/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 33749961ed60
# Step 12/32 : COPY index.py           .
#  ---> Using cache
#  ---> 2afdd8ed44fd
# Step 13/32 : COPY requirements.txt   .
#  ---> Using cache
#  ---> 8811149c11a1
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Using cache
#  ---> 641b7b7a0808
# Step 15/32 : USER app
#  ---> Using cache
#  ---> 9242f79c9cf6
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Using cache
#  ---> 3d3ee3fed927
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Using cache
#  ---> c3f310a1c880
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Using cache
#  ---> e564580ecb37
# Step 19/32 : RUN mkdir -p function
#  ---> Using cache
#  ---> 8f8043593750
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Using cache
#  ---> 8550feab058a
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Using cache
#  ---> db1db71b8182
# Step 22/32 : COPY function/requirements.txt	.
#  ---> Using cache
#  ---> d6427d438090
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python && pip install --upgrade Pillow --target=/home/app/python
#  ---> Using cache
#  ---> 264aa8b3d026
# Step 24/32 : WORKDIR /home/app/
#  ---> Using cache
#  ---> 4ee78441aff0
# Step 25/32 : USER root
#  ---> Using cache
#  ---> eea1571a8050
# Step 26/32 : COPY function           function
#  ---> 12a86b31f676
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 1ae968ec8c13
# Removing intermediate container 1ae968ec8c13
#  ---> 614a6c4b8120
# Step 28/32 : USER app
#  ---> Running in 28297d15b540
# Removing intermediate container 28297d15b540
#  ---> fbcce8fe54bd
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 299f3b684836
# Removing intermediate container 299f3b684836
#  ---> d56748f5dc1f
# Step 30/32 : EXPOSE 8080
#  ---> Running in d75ca3a228e4
# Removing intermediate container d75ca3a228e4
#  ---> f67128e04823
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 473c024567b5
# Removing intermediate container 473c024567b5
#  ---> e2b31300bf99
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 43f3f077ec95
# Removing intermediate container 43f3f077ec95
#  ---> 287b2297d215
# Successfully built 287b2297d215
# Successfully tagged k.harbor.siat.ac.cn/openfaas/facerecognition-general:1.3
# Image: k.harbor.siat.ac.cn/openfaas/facerecognition-general:1.3 built.
# [0] < Building facerecognition-general done in 171.69s.
# [0] Worker done.
#
# Total build time: 1549.31s
#
# [0] > Pushing svr-general [k.harbor.siat.ac.cn/openfaas/svr-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/svr-general]
# 21e52998a528: Preparing
# ad507729fc9c: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 782c377e744c: Waiting
# 0f2ad34f241b: Preparing
# 4fce7e36cd4b: Waiting
# f13cae6d5fe9: Preparing
# 00c4ab19a265: Waiting
# 0f94430f88c9: Waiting
# 7b4724067e57: Waiting
# b987bf55f43d: Waiting
# 8729b6a044ba: Preparing
# 5c0fbc8e3c3d: Preparing
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# c5f1d4dd95f0: Waiting
# 5c0fbc8e3c3d: Waiting
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# c94dc8fa3d89: Preparing
# 6a25221bdf24: Waiting
# b578f477cd5d: Waiting
# b298f9991a11: Waiting
# c94dc8fa3d89: Waiting
# ddb8cfbeaf2e: Pushed
# 1e2330b009f1: Pushed
# 89af213fc6c1: Pushed
# 4fce7e36cd4b: Pushed
# ad507729fc9c: Pushed
# 0f94430f88c9: Pushed
# 9f3e0df3ef36: Pushed
# 782c377e744c: Pushed
# 00c4ab19a265: Pushed
# b987bf55f43d: Pushed
# 7b4724067e57: Pushed
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# 5c0fbc8e3c3d: Layer already exists
# c5f1d4dd95f0: Layer already exists
# 6a25221bdf24: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# 0f2ad34f241b: Pushed
# 38064bcd2e6f: Pushed
# 21e52998a528: Pushed
# 1.3: digest: sha256:2a3f6900c4cc25fe1f5116807df3617c4dded985420e09a118b1bc3a52eb8f04 size: 5140
# [0] < Pushing svr-general [k.harbor.siat.ac.cn/openfaas/svr-general:1.3] done.
# [0] > Pushing sgdregressor-general [k.harbor.siat.ac.cn/openfaas/sgdregressor-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/sgdregressor-general]
# 12d5c3448cbb: Preparing
# 4bab3ace0336: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# 8729b6a044ba: Preparing
# 5c0fbc8e3c3d: Preparing
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# 89af213fc6c1: Waiting
# 4fce7e36cd4b: Waiting
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# 782c377e744c: Waiting
# c94dc8fa3d89: Preparing
# 00c4ab19a265: Waiting
# 9f3e0df3ef36: Waiting
# 0f94430f88c9: Waiting
# b987bf55f43d: Waiting
# 8729b6a044ba: Waiting
# 6a25221bdf24: Waiting
# c5f1d4dd95f0: Waiting
# 7b4724067e57: Waiting
# 5c0fbc8e3c3d: Waiting
# b578f477cd5d: Waiting
# 0f2ad34f241b: Waiting
# b298f9991a11: Waiting
# 38064bcd2e6f: Mounted from openfaas/svr-general
# ddb8cfbeaf2e: Mounted from openfaas/svr-general
# 1e2330b009f1: Mounted from openfaas/svr-general
# 4bab3ace0336: Pushed
# 4fce7e36cd4b: Mounted from openfaas/svr-general
# 89af213fc6c1: Mounted from openfaas/svr-general
# 0f94430f88c9: Mounted from openfaas/svr-general
# 9f3e0df3ef36: Mounted from openfaas/svr-general
# 782c377e744c: Mounted from openfaas/svr-general
# 00c4ab19a265: Mounted from openfaas/svr-general
# b987bf55f43d: Mounted from openfaas/svr-general
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# 5c0fbc8e3c3d: Layer already exists
# c5f1d4dd95f0: Layer already exists
# 7b4724067e57: Mounted from openfaas/svr-general
# 0f2ad34f241b: Mounted from openfaas/svr-general
# 6a25221bdf24: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# 12d5c3448cbb: Pushed
# 1.3: digest: sha256:0b02752273674e5c3f5f73aca4f739e07ec4cea4fcfe0f82faab9aaf5310862f size: 5140
# [0] < Pushing sgdregressor-general [k.harbor.siat.ac.cn/openfaas/sgdregressor-general:1.3] done.
# [0] > Pushing facerecognition-general [k.harbor.siat.ac.cn/openfaas/facerecognition-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/facerecognition-general]
# 16f73d8a50c2: Preparing
# 88929f7267c6: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# 8729b6a044ba: Preparing
# 9f3e0df3ef36: Waiting
# 5c0fbc8e3c3d: Preparing
# 89af213fc6c1: Waiting
# 0f94430f88c9: Waiting
# c5f1d4dd95f0: Preparing
# 4fce7e36cd4b: Waiting
# 7b4724067e57: Waiting
# 782c377e744c: Waiting
# 0f2ad34f241b: Waiting
# b987bf55f43d: Waiting
# 6a25221bdf24: Preparing
# 8729b6a044ba: Waiting
# f13cae6d5fe9: Waiting
# 5c0fbc8e3c3d: Waiting
# b578f477cd5d: Preparing
# 6a25221bdf24: Waiting
# b298f9991a11: Preparing
# c94dc8fa3d89: Preparing
# c94dc8fa3d89: Waiting
# 1e2330b009f1: Mounted from openfaas/sgdregressor-general
# 38064bcd2e6f: Mounted from openfaas/sgdregressor-general
# ddb8cfbeaf2e: Mounted from openfaas/sgdregressor-general
# 89af213fc6c1: Mounted from openfaas/sgdregressor-general
# 4fce7e36cd4b: Mounted from openfaas/sgdregressor-general
# 0f94430f88c9: Mounted from openfaas/sgdregressor-general
# 9f3e0df3ef36: Mounted from openfaas/sgdregressor-general
# 88929f7267c6: Pushed
# 782c377e744c: Mounted from openfaas/sgdregressor-general
# 00c4ab19a265: Mounted from openfaas/sgdregressor-general
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# b987bf55f43d: Mounted from openfaas/sgdregressor-general
# 7b4724067e57: Mounted from openfaas/sgdregressor-general
# 0f2ad34f241b: Mounted from openfaas/sgdregressor-general
# 5c0fbc8e3c3d: Layer already exists
# c5f1d4dd95f0: Layer already exists
# b578f477cd5d: Layer already exists
# 6a25221bdf24: Layer already exists
# c94dc8fa3d89: Layer already exists
# b298f9991a11: Layer already exists
# 16f73d8a50c2: Pushed
# 1.3: digest: sha256:b0f8d2f2ef1a4fcb5cbca1cf7750e38793771b78b780fc7c14ecba082ae2cbd2 size: 5140
# [0] < Pushing facerecognition-general [k.harbor.siat.ac.cn/openfaas/facerecognition-general:1.3] done.
# [0] > Pushing sgdclassifier-general [k.harbor.siat.ac.cn/openfaas/sgdclassifier-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/sgdclassifier-general]
# a7296f2f8433: Preparing
# 461238569f81: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 89af213fc6c1: Waiting
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# 0f94430f88c9: Waiting
# 782c377e744c: Waiting
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 00c4ab19a265: Waiting
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# b987bf55f43d: Waiting
# 8729b6a044ba: Preparing
# f13cae6d5fe9: Waiting
# 5c0fbc8e3c3d: Preparing
# 8729b6a044ba: Waiting
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# 5c0fbc8e3c3d: Waiting
# c5f1d4dd95f0: Waiting
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# c94dc8fa3d89: Preparing
# 6a25221bdf24: Waiting
# b578f477cd5d: Waiting
# b298f9991a11: Waiting
# ddb8cfbeaf2e: Mounted from openfaas/facerecognition-general
# 1e2330b009f1: Mounted from openfaas/facerecognition-general
# 38064bcd2e6f: Mounted from openfaas/facerecognition-general
# 89af213fc6c1: Mounted from openfaas/facerecognition-general
# 4fce7e36cd4b: Mounted from openfaas/facerecognition-general
# 0f94430f88c9: Mounted from openfaas/facerecognition-general
# 461238569f81: Pushed
# 9f3e0df3ef36: Mounted from openfaas/facerecognition-general
# 782c377e744c: Mounted from openfaas/facerecognition-general
# 00c4ab19a265: Mounted from openfaas/facerecognition-general
# b987bf55f43d: Mounted from openfaas/facerecognition-general
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# 5c0fbc8e3c3d: Layer already exists
# 7b4724067e57: Mounted from openfaas/facerecognition-general
# c5f1d4dd95f0: Layer already exists
# 0f2ad34f241b: Mounted from openfaas/facerecognition-general
# 6a25221bdf24: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# a7296f2f8433: Pushed
# 1.3: digest: sha256:9b0a4afd2e28d9783dd314950aef0ed0beabd6babfee13daefc3abc683c119ac size: 5139
# [0] < Pushing sgdclassifier-general [k.harbor.siat.ac.cn/openfaas/sgdclassifier-general:1.3] done.
# [0] > Pushing randomforestregressor-general [k.harbor.siat.ac.cn/openfaas/randomforestregressor-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/randomforestregressor-general]
# 9598575049cd: Preparing
# 44dafdbcede3: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# 8729b6a044ba: Preparing
# 4fce7e36cd4b: Waiting
# 9f3e0df3ef36: Waiting
# 5c0fbc8e3c3d: Preparing
# 00c4ab19a265: Waiting
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# 0f94430f88c9: Waiting
# 782c377e744c: Waiting
# 7b4724067e57: Waiting
# b578f477cd5d: Preparing
# 0f2ad34f241b: Waiting
# b298f9991a11: Preparing
# c94dc8fa3d89: Preparing
# b578f477cd5d: Waiting
# b298f9991a11: Waiting
# c94dc8fa3d89: Waiting
# 89af213fc6c1: Waiting
# 5c0fbc8e3c3d: Waiting
# c5f1d4dd95f0: Waiting
# 38064bcd2e6f: Mounted from openfaas/sgdclassifier-general
# 1e2330b009f1: Mounted from openfaas/sgdclassifier-general
# ddb8cfbeaf2e: Mounted from openfaas/sgdclassifier-general
# 89af213fc6c1: Mounted from openfaas/sgdclassifier-general
# 4fce7e36cd4b: Mounted from openfaas/sgdclassifier-general
# 0f94430f88c9: Mounted from openfaas/sgdclassifier-general
# 9f3e0df3ef36: Mounted from openfaas/sgdclassifier-general
# 782c377e744c: Mounted from openfaas/sgdclassifier-general
# 00c4ab19a265: Mounted from openfaas/sgdclassifier-general
# b987bf55f43d: Mounted from openfaas/sgdclassifier-general
# 7b4724067e57: Mounted from openfaas/sgdclassifier-general
# f13cae6d5fe9: Layer already exists
# 0f2ad34f241b: Mounted from openfaas/sgdclassifier-general
# 5c0fbc8e3c3d: Layer already exists
# 8729b6a044ba: Layer already exists
# 6a25221bdf24: Layer already exists
# c5f1d4dd95f0: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# 44dafdbcede3: Pushed
# 9598575049cd: Pushed
# 1.3: digest: sha256:8c41d37397ea1abc3518a6730d7a8d3c4c4aaf678b1facee39e1ecfcef772d3a size: 5141
# [0] < Pushing randomforestregressor-general [k.harbor.siat.ac.cn/openfaas/randomforestregressor-general:1.3] done.
# [0] > Pushing perceptron-general [k.harbor.siat.ac.cn/openfaas/perceptron-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/perceptron-general]
# 41109387aa48: Preparing
# efeaf2088650: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# 8729b6a044ba: Preparing
# 5c0fbc8e3c3d: Preparing
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# 782c377e744c: Waiting
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# 0f94430f88c9: Waiting
# c94dc8fa3d89: Preparing
# 89af213fc6c1: Waiting
# 00c4ab19a265: Waiting
# b987bf55f43d: Waiting
# 4fce7e36cd4b: Waiting
# 5c0fbc8e3c3d: Waiting
# 9f3e0df3ef36: Waiting
# b298f9991a11: Waiting
# 7b4724067e57: Waiting
# c94dc8fa3d89: Waiting
# 6a25221bdf24: Waiting
# 0f2ad34f241b: Waiting
# b578f477cd5d: Waiting
# c5f1d4dd95f0: Waiting
# f13cae6d5fe9: Waiting
# 8729b6a044ba: Waiting
# 1e2330b009f1: Mounted from openfaas/randomforestregressor-general
# ddb8cfbeaf2e: Mounted from openfaas/randomforestregressor-general
# 38064bcd2e6f: Mounted from openfaas/randomforestregressor-general
# efeaf2088650: Pushed
# 89af213fc6c1: Mounted from openfaas/randomforestregressor-general
# 4fce7e36cd4b: Mounted from openfaas/randomforestregressor-general
# 0f94430f88c9: Mounted from openfaas/randomforestregressor-general
# 9f3e0df3ef36: Mounted from openfaas/randomforestregressor-general
# 782c377e744c: Mounted from openfaas/randomforestregressor-general
# 00c4ab19a265: Mounted from openfaas/randomforestregressor-general
# b987bf55f43d: Mounted from openfaas/randomforestregressor-general
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# 7b4724067e57: Mounted from openfaas/randomforestregressor-general
# 5c0fbc8e3c3d: Layer already exists
# c5f1d4dd95f0: Layer already exists
# 0f2ad34f241b: Mounted from openfaas/randomforestregressor-general
# 6a25221bdf24: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# 41109387aa48: Pushed
# 1.3: digest: sha256:f1f8140295c498bbdacf93671cda58158e1192537993feb16a2259e8a58c6d73 size: 5139
# [0] < Pushing perceptron-general [k.harbor.siat.ac.cn/openfaas/perceptron-general:1.3] done.
# [0] > Pushing multinomialnb-general [k.harbor.siat.ac.cn/openfaas/multinomialnb-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/multinomialnb-general]
# 518ef0898059: Preparing
# 4acd5bf4fa20: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# 4fce7e36cd4b: Waiting
# 8729b6a044ba: Preparing
# 89af213fc6c1: Waiting
# 5c0fbc8e3c3d: Preparing
# 9f3e0df3ef36: Waiting
# c5f1d4dd95f0: Preparing
# 782c377e744c: Waiting
# 0f94430f88c9: Waiting
# 8729b6a044ba: Waiting
# 0f2ad34f241b: Waiting
# b987bf55f43d: Waiting
# f13cae6d5fe9: Waiting
# 6a25221bdf24: Preparing
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# 6a25221bdf24: Waiting
# c94dc8fa3d89: Preparing
# b298f9991a11: Waiting
# b578f477cd5d: Waiting
# ddb8cfbeaf2e: Mounted from openfaas/perceptron-general
# 1e2330b009f1: Mounted from openfaas/perceptron-general
# 38064bcd2e6f: Mounted from openfaas/perceptron-general
# 89af213fc6c1: Mounted from openfaas/perceptron-general
# 4fce7e36cd4b: Mounted from openfaas/perceptron-general
# 0f94430f88c9: Mounted from openfaas/perceptron-general
# 4acd5bf4fa20: Pushed
# 9f3e0df3ef36: Mounted from openfaas/perceptron-general
# 782c377e744c: Mounted from openfaas/perceptron-general
# 00c4ab19a265: Mounted from openfaas/perceptron-general
# b987bf55f43d: Mounted from openfaas/perceptron-general
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# c5f1d4dd95f0: Layer already exists
# 5c0fbc8e3c3d: Layer already exists
# 7b4724067e57: Mounted from openfaas/perceptron-general
# 6a25221bdf24: Layer already exists
# 0f2ad34f241b: Mounted from openfaas/perceptron-general
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# 518ef0898059: Pushed
# 1.3: digest: sha256:97bb6dc312fc734135efd8a66c897978a2297b145f2f64def3470b46f0b54fc1 size: 5140
# [0] < Pushing multinomialnb-general [k.harbor.siat.ac.cn/openfaas/multinomialnb-general:1.3] done.
# [0] > Pushing passiveaggressiveclassifier-general [k.harbor.siat.ac.cn/openfaas/passiveaggressiveclassifier-general:1.3].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/passiveaggressiveclassifier-general]
# 32ad7915f696: Preparing
# bc0c36532a71: Preparing
# 38064bcd2e6f: Preparing
# ddb8cfbeaf2e: Preparing
# 1e2330b009f1: Preparing
# 89af213fc6c1: Preparing
# 4fce7e36cd4b: Preparing
# 0f94430f88c9: Preparing
# 9f3e0df3ef36: Preparing
# 782c377e744c: Preparing
# 00c4ab19a265: Preparing
# b987bf55f43d: Preparing
# 7b4724067e57: Preparing
# 0f2ad34f241b: Preparing
# 0f2ad34f241b: Preparing
# f13cae6d5fe9: Preparing
# 8729b6a044ba: Preparing
# 5c0fbc8e3c3d: Preparing
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# 89af213fc6c1: Waiting
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# c94dc8fa3d89: Preparing
# 4fce7e36cd4b: Waiting
# 0f94430f88c9: Waiting
# c5f1d4dd95f0: Waiting
# b298f9991a11: Waiting
# c94dc8fa3d89: Waiting
# 6a25221bdf24: Waiting
# 9f3e0df3ef36: Waiting
# 0f2ad34f241b: Waiting
# b578f477cd5d: Waiting
# f13cae6d5fe9: Waiting
# 782c377e744c: Waiting
# 00c4ab19a265: Waiting
# 8729b6a044ba: Waiting
# 7b4724067e57: Waiting
# 5c0fbc8e3c3d: Waiting
# ddb8cfbeaf2e: Mounted from openfaas/multinomialnb-general
# 1e2330b009f1: Mounted from openfaas/multinomialnb-general
# 38064bcd2e6f: Mounted from openfaas/multinomialnb-general
# bc0c36532a71: Pushed
# 89af213fc6c1: Mounted from openfaas/multinomialnb-general
# 4fce7e36cd4b: Mounted from openfaas/multinomialnb-general
# 0f94430f88c9: Mounted from openfaas/multinomialnb-general
# 9f3e0df3ef36: Mounted from openfaas/multinomialnb-general
# 782c377e744c: Mounted from openfaas/multinomialnb-general
# 00c4ab19a265: Mounted from openfaas/multinomialnb-general
# b987bf55f43d: Mounted from openfaas/multinomialnb-general
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# 7b4724067e57: Mounted from openfaas/multinomialnb-general
# 5c0fbc8e3c3d: Layer already exists
# c5f1d4dd95f0: Layer already exists
# 0f2ad34f241b: Mounted from openfaas/multinomialnb-general
# 6a25221bdf24: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# 32ad7915f696: Pushed
# 1.3: digest: sha256:cadd5736dfcca23e27b158a25b102cef897852e60687dccae8b91637eb3cbcb2 size: 5139
# [0] < Pushing passiveaggressiveclassifier-general [k.harbor.siat.ac.cn/openfaas/passiveaggressiveclassifier-general:1.3] done.
# [0] Worker done.
#
# Deploying: perceptron-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/perceptron-general
#
# Deploying: multinomialnb-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/multinomialnb-general
#
# Deploying: passiveaggressiveclassifier-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/passiveaggressiveclassifier-general
#
# Deploying: svr-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/svr-general
#
# Deploying: sgdregressor-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/sgdregressor-general
#
# Deploying: facerecognition-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/facerecognition-general
#
# Deploying: sgdclassifier-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/sgdclassifier-general
#
# Deploying: randomforestregressor-general.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/randomforestregressor-general

# %%
update_openfaas(path_bigdata)
# Out:
# /home/pengshijie/bbserverlees/DIC/BigData/openfaas
# Fetch templates from repository: https://github.com/openfaas/templates.git at
# 2023/08/16 02:28:14 Attempting to expand templates from https://github.com/openfaas/templates.git
# 2023/08/16 02:28:15 Cannot overwrite the following 16 template(s): [csharp dockerfile go java11 java11-vert-x node node14 node16 node17 node18 php7 php8 python python3 python3-debian ruby]
# 2023/08/16 02:28:15 Fetched 0 template(s) : [] from https://github.com/openfaas/templates.git
# [0] > Building bigdata.
# Clearing temporary build folder: ./build/bigdata/
# Preparing: ./map-reduce/ build/bigdata/function
# Building: k.harbor.siat.ac.cn/openfaas/map-reduce:1.0.1 with python3-debian template. Please wait..
# Sending build context to Docker daemon  8.704kB
#
# Step 1/32 : ARG PYTHON_VERSION=3
# Step 2/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} ghcr.io/openfaas/classic-watchdog:0.2.1 as watchdog
#  ---> 021a98fdbddd
# Step 3/32 : FROM --platform=${TARGETPLATFORM:-linux/amd64} python:${PYTHON_VERSION}
#  ---> a5fee9aa0e3a
# Step 4/32 : ARG TARGETPLATFORM
#  ---> Running in def5da93793a
# Removing intermediate container def5da93793a
#  ---> bc32014dd5ad
# Step 5/32 : ARG BUILDPLATFORM
#  ---> Running in 5ce33045899e
# Removing intermediate container 5ce33045899e
#  ---> 57e7e3a71ff1
# Step 6/32 : ARG ADDITIONAL_PACKAGE
#  ---> Running in e806c4a5eaa3
# Removing intermediate container e806c4a5eaa3
#  ---> 6c7829b857f9
# Step 7/32 : COPY --from=watchdog /fwatchdog /usr/bin/fwatchdog
#  ---> 71862d6ef780
# Step 8/32 : RUN chmod +x /usr/bin/fwatchdog
#  ---> Running in 4ff2091938d3
# Removing intermediate container 4ff2091938d3
#  ---> 2c64943934ed
# Step 9/32 : RUN apt-get update     && apt-get install -y ca-certificates ${ADDITIONAL_PACKAGE}     && rm -rf /var/lib/apt/lists/
#  ---> Running in 09bfaa19d55e
# Get:1 http://deb.debian.org/debian bookworm InRelease [151 kB]
# Get:2 http://deb.debian.org/debian bookworm-updates InRelease [52.1 kB]
# Get:3 http://deb.debian.org/debian-security bookworm-security InRelease [48.0 kB]
# Get:4 http://deb.debian.org/debian bookworm/main amd64 Packages [8906 kB]
# Get:5 http://deb.debian.org/debian bookworm-updates/main amd64 Packages [4732 B]
# Get:6 http://deb.debian.org/debian-security bookworm-security/main amd64 Packages [57.2 kB]
# Fetched 9219 kB in 7s (1396 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ca-certificates is already the newest version (20230311).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Removing intermediate container 09bfaa19d55e
#  ---> 94a480e8fa91
# Step 10/32 : RUN groupadd app && useradd -r -g app app
#  ---> Running in 30e3cc398fcd
# Removing intermediate container 30e3cc398fcd
#  ---> a93772f89209
# Step 11/32 : WORKDIR /home/app/
#  ---> Running in 3370fed635ee
# Removing intermediate container 3370fed635ee
#  ---> 0da5499d4c0e
# Step 12/32 : COPY index.py           .
#  ---> 613d20cb2c68
# Step 13/32 : COPY requirements.txt   .
#  ---> 595f6fb4b18f
# Step 14/32 : RUN chown -R app /home/app &&     mkdir -p /home/app/python && chown -R app /home/app
#  ---> Running in 09851f2b592d
# Removing intermediate container 09851f2b592d
#  ---> 0fc1f62e0f59
# Step 15/32 : USER app
#  ---> Running in 19fb64d32868
# Removing intermediate container 19fb64d32868
#  ---> 0dcd85d7af26
# Step 16/32 : ENV PATH=$PATH:/home/app/.local/bin:/home/app/python/bin/
#  ---> Running in c929342d9f7b
# Removing intermediate container c929342d9f7b
#  ---> c9a52d5efa41
# Step 17/32 : ENV PYTHONPATH=$PYTHONPATH:/home/app/python
#  ---> Running in 00d417afe14f
# Removing intermediate container 00d417afe14f
#  ---> e5ad8ca99b78
# Step 18/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Running in 966ea86cc8be
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Removing intermediate container 966ea86cc8be
#  ---> a785f7649519
# Step 19/32 : RUN mkdir -p function
#  ---> Running in c5704df873ea
# Removing intermediate container c5704df873ea
#  ---> cd6992d33a83
# Step 20/32 : RUN touch ./function/__init__.py
#  ---> Running in d20a0fcbdc34
# Removing intermediate container d20a0fcbdc34
#  ---> cdab00c57a79
# Step 21/32 : WORKDIR /home/app/function/
#  ---> Running in 974bc011f126
# Removing intermediate container 974bc011f126
#  ---> 60c3d61ce138
# Step 22/32 : COPY function/requirements.txt	.
#  ---> 12cc0bbe730d
# Step 23/32 : RUN pip install -r requirements.txt --target=/home/app/python
#  ---> Running in f313a94d812f
# Collecting collection (from -r requirements.txt (line 1))
#   Downloading collection-0.1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: collection
#   Building wheel for collection (setup.py): started
#   Building wheel for collection (setup.py): finished with status 'done'
#   Created wheel for collection: filename=collection-0.1.6-py3-none-any.whl size=5099 sha256=1df9eac270d2f333b3c4f7e02a97476606bf900cdc1009dca620d63321cb2c34
#   Stored in directory: /home/app/.cache/pip/wheels/1c/b3/7a/6dd2fd1aa32817819c8c91da9a6b5919148da6eb5855ab0986
# Successfully built collection
# Installing collected packages: collection
# Successfully installed collection-0.1.6
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Removing intermediate container f313a94d812f
#  ---> b0b7b8c4f553
# Step 24/32 : WORKDIR /home/app/
#  ---> Running in 46338bfcbf38
# Removing intermediate container 46338bfcbf38
#  ---> 268fe42e668a
# Step 25/32 : USER root
#  ---> Running in a99710635eb3
# Removing intermediate container a99710635eb3
#  ---> a35ad2535a07
# Step 26/32 : COPY function           function
#  ---> 4520830024c5
# Step 27/32 : RUN chown -R app:app ./ &&     chmod -R 777 /home/app/python
#  ---> Running in 075be9ab7bb9
# Removing intermediate container 075be9ab7bb9
#  ---> ea6dad9ba81f
# Step 28/32 : USER app
#  ---> Running in 136ee488bb7a
# Removing intermediate container 136ee488bb7a
#  ---> e7666b13afc2
# Step 29/32 : ENV fprocess="python3 index.py"
#  ---> Running in 46415bf0391e
# Removing intermediate container 46415bf0391e
#  ---> f2c9ea0f89b6
# Step 30/32 : EXPOSE 8080
#  ---> Running in db4cb571f1c8
# Removing intermediate container db4cb571f1c8
#  ---> 6fa5ea2c0775
# Step 31/32 : HEALTHCHECK --interval=3s CMD [ -e /tmp/.lock ] || exit 1
#  ---> Running in 8ffd11bb7e3f
# Removing intermediate container 8ffd11bb7e3f
#  ---> 704e2ee9b4a9
# Step 32/32 : CMD ["fwatchdog"]
#  ---> Running in 718b0249a8ad
# Removing intermediate container 718b0249a8ad
#  ---> a0a5ab8a90f0
# Successfully built a0a5ab8a90f0
# Successfully tagged k.harbor.siat.ac.cn/openfaas/map-reduce:1.0.1
# Image: k.harbor.siat.ac.cn/openfaas/map-reduce:1.0.1 built.
# [0] < Building bigdata done in 68.07s.
# [0] Worker done.
#
# Total build time: 68.07s
#
# [0] > Pushing bigdata [k.harbor.siat.ac.cn/openfaas/map-reduce:1.0.1].
# The push refers to repository [k.harbor.siat.ac.cn/openfaas/map-reduce]
# 17d01da4ab40: Preparing
# ac13ab567b96: Preparing
# 69e4e0eac538: Preparing
# fdcbedf42ec4: Preparing
# 2811257a83d9: Preparing
# 5355bf443be0: Preparing
# aadf793d6587: Preparing
# 0802207ac622: Preparing
# 86f000221b27: Preparing
# 5183a8df263f: Preparing
# 4571fb0a3f12: Preparing
# aadf793d6587: Waiting
# fd2254be6533: Preparing
# 5355bf443be0: Waiting
# c2fd58d3846d: Preparing
# 0802207ac622: Waiting
# 5183a8df263f: Waiting
# 86f000221b27: Waiting
# d383560c784d: Preparing
# fd2254be6533: Waiting
# 4571fb0a3f12: Waiting
# d383560c784d: Preparing
# f13cae6d5fe9: Preparing
# c2fd58d3846d: Waiting
# d383560c784d: Waiting
# 8729b6a044ba: Preparing
# 5c0fbc8e3c3d: Preparing
# f13cae6d5fe9: Waiting
# c5f1d4dd95f0: Preparing
# 6a25221bdf24: Preparing
# b578f477cd5d: Preparing
# b298f9991a11: Preparing
# c5f1d4dd95f0: Waiting
# 6a25221bdf24: Waiting
# 5c0fbc8e3c3d: Waiting
# c94dc8fa3d89: Preparing
# b298f9991a11: Waiting
# c94dc8fa3d89: Waiting
# ac13ab567b96: Pushed
# fdcbedf42ec4: Pushed
# 2811257a83d9: Pushed
# 69e4e0eac538: Pushed
# 17d01da4ab40: Pushed
# 5355bf443be0: Pushed
# aadf793d6587: Pushed
# 0802207ac622: Pushed
# 86f000221b27: Pushed
# 5183a8df263f: Pushed
# f13cae6d5fe9: Layer already exists
# 8729b6a044ba: Layer already exists
# 4571fb0a3f12: Pushed
# 5c0fbc8e3c3d: Layer already exists
# fd2254be6533: Pushed
# c2fd58d3846d: Pushed
# 6a25221bdf24: Layer already exists
# c5f1d4dd95f0: Layer already exists
# b578f477cd5d: Layer already exists
# b298f9991a11: Layer already exists
# c94dc8fa3d89: Layer already exists
# d383560c784d: Pushed
# 1.0.1: digest: sha256:88aec254efbe5182d9b8dd0b3ce24ff718ff28a40de33ef0726368a3400d1c7a size: 5128
# [0] < Pushing bigdata [k.harbor.siat.ac.cn/openfaas/map-reduce:1.0.1] done.
# [0] Worker done.
#
# Deploying: bigdata.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/bigdata

# %%
update_openfaas(path_stream)
# Out:
# /home/pengshijie/bbserverlees/DIC/Stream/openfaas
# Deploying: stream.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/stream

# %%
update_openfaas(path_web)
# Out:
# /home/pengshijie/bbserverlees/DIC/WebServices/openfaas/python-code
# Deploying: hello-python.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/hello-python
#
# Deploying: hash-python.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/hash-python
#
# Deploying: sort-python.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/sort-python
#
# Deploying: md5-python.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/md5-python
#
# Deploying: cryptography-python.
# WARNING! You are not using an encrypted connection to the gateway, consider using HTTPS.
#
# Deployed. 202 Accepted.
# URL: http://serverless.siat.ac.cn:31112/function/cryptography-python

# %%
! kubectl get pod  -n openfaas-fn
# Out:
# NAME                                                   READY   STATUS            RESTARTS   AGE
# cryptography-python-869dfb6d64-p2xrq                   0/2     Init:0/1          0          4s
# facerecognition-general-6f6767d8cd-42pq7               0/2     Init:0/1          0          15s
# hash-python-6548df7b96-s4q85                           0/2     Init:0/1          0          7s
# hello-python-54748dff96-zln7x                          0/2     Init:0/1          0          8s
# md5-python-79466f96b4-ztcqc                            0/2     Init:0/1          0          6s
# multinomialnb-general-848765c44-h8drm                  0/2     PodInitializing   0          16s
# passiveaggressiveclassifier-general-66988fc498-mxprq   0/2     Init:0/1          0          16s
# perceptron-general-6bf9cc598b-7lqcc                    0/2     PodInitializing   0          16s
# randomforestregressor-general-757cc7c878-p6pqs         0/2     PodInitializing   0          16s
# sgdclassifier-general-c6d588d64-hnpcg                  0/2     PodInitializing   0          16s
# sgdregressor-general-76dc6659cd-wq6lw                  0/2     Init:0/1          0          16s
# sort-python-86c79b84f6-djrmm                           0/2     Init:0/1          0          6s
# svr-general-fffddbfb4-r9ncl                            0/2     Init:0/1          0          16s

# %%
import time
# action_names = ['hello-python', 'hash-python', 'cryptography-python', 'md5-python', 'sort-python', 'facerecognition-general', 'multinomialnb-general',
#                 'passiveaggressiveclassifier-general', 'perceptron-general', 'randomforestregressor-general', 'sgdclassifier-general', 'sgdregressor-general', 'svr-general', 'bigdata', 'stream']
action_names = ['hello-python', 'hash-python', 'cryptography-python', 'md5-python', 'sort-python', 'facerecognition-general', 'multinomialnb-general',
                'passiveaggressiveclassifier-general', 'perceptron-general', 'randomforestregressor-general', 'sgdclassifier-general', 'sgdregressor-general', 'svr-general']
for i in action_names:
    start  = time.time()
    cmd = 'curl -s http://serverless.siat.ac.cn:31112/function/{function}.openfaas-fn'
    os.system(cmd.format(function=i))
    end = time.time()
    print("{function}耗时:".format(function=i), end-start)
# Out:
# {"token": "Hello from helper.py, stranger!", "startTime": 1692174367.2318306}
# hello-python耗时: 0.12387967109680176
# {"token": "8310271321522731259", "startTime": 1692174367.3475385}
# hash-python耗时: 0.13877081871032715
# {"token": "b'gAAAAABk3Igft-nDcLKvio8EiStMcGtnxKpwE25yAm0AN3jkxK-m81DHmu-taD3-CkKyVjZ0jW-KDMe091Dh9wpThyZIzqAvyw=='", "startTime": 1692174367.5354078}
# cryptography-python耗时: 0.3852078914642334
# {"token": "04b463d267c4f68ead02c3bdd44fe64c", "startTime": 1692174367.8681426}
# md5-python耗时: 0.13603615760803223
# {"token": "[0, 1, 1, 2, 2, 3, 4, 4, 5, 5, 6, 6, 7, 7, 7, 8, 8, 9, 10, 20, 34, 88, 2232]", "startTime": 1692174368.0195248}
# sort-python耗时: 0.12684273719787598
# {"token": "inference finished", "startTime": 1692174368.4703948}
# facerecognition-general耗时: 1.4506118297576904
# {"token": "inference finished", "startTime": 1692174369.991271}
# multinomialnb-general耗时: 1.4865410327911377
# {"token": "inference finished", "startTime": 1692174371.302414}
# passiveaggressiveclassifier-general耗时: 1.0382089614868164
# {"token": "inference finished", "startTime": 1692174372.4569476}
# perceptron-general耗时: 1.3931457996368408
# {"token": "inference finished", "startTime": 1692174373.8530881}
# randomforestregressor-general耗时: 2.3882319927215576
# {"token": "inference finished", "startTime": 1692174376.2511938}
# sgdclassifier-general耗时: 1.2809457778930664
# {"token": "inference finished", "startTime": 1692174377.4946804}
# sgdregressor-general耗时: 1.4658372402191162
# {"token": "inference finished", "startTime": 1692174379.0031378}
# svr-general耗时: 3.6881041526794434

# %%
# # 删除所有函数
# action_names = ['hello-python', 'hash-python', 'cryptography-python', 'md5-python', 'sort-python']
action_names = ['hello-python', 'hash-python', 'cryptography-python', 'md5-python', 'sort-python', 'facerecognition-general', 'multinomialnb-general','passiveaggressiveclassifier-general', 'perceptron-general', 'randomforestregressor-general', 'sgdclassifier-general', 'sgdregressor-general', 'svr-general']
# action_names = ['bigdata', 'stream']
for i in action_names:
    cmd = f'faas-cli remove {i} --gateway=http://serverless.siat.ac.cn:31112'
    print(subprocess.getoutput(cmd))
    # os.system(cmd.format(function=i))
# Out:
# Deleting: hello-python.
# No existing function to remove
# Deleting: hash-python.
# No existing function to remove
# Deleting: cryptography-python.
# No existing function to remove
# Deleting: md5-python.
# No existing function to remove
# Deleting: sort-python.
# No existing function to remove
# Deleting: facerecognition-general.
# Removing old function.
# Deleting: multinomialnb-general.
# Removing old function.
# Deleting: passiveaggressiveclassifier-general.
# Removing old function.
# Deleting: perceptron-general.
# Removing old function.
# Deleting: randomforestregressor-general.
# Removing old function.
# Deleting: sgdclassifier-general.
# Removing old function.
# Deleting: sgdregressor-general.
# Removing old function.
# Deleting: svr-general.
# Removing old function.

# %%
# setting autoscaling for all functions

cmd = 'kubectl autoscale deployment {function} -n openfaas-fn --cpu-percent=30  --min=1  --max=30'

cmd_watch = 'kubectl get hpa/{function} -n openfaas-fn'
cmd_deleteHPA = 'kubectl delete hpa {function} -n openfaas-fn'
cmd_changeCpu='kubectl delete hpa {function} -n openfaas-fn && kubectl autoscale deployment {function} -n openfaas-fn --cpu-percent=20 --min=1  --max=20'

# action_names = ['hello-python', 'hash-python', 'cryptography-python', 'md5-python', 'sort-python', 'facerecognition-general', 'multinomialnb-general','passiveaggressiveclassifier-general', 'perceptron-general', 'randomforestregressor-general', 'sgdclassifier-general', 'sgdregressor-general', 'svr-general', 'bigdata', 'stream']
action_names = ['hello-python', 'hash-python', 'cryptography-python', 'md5-python', 'sort-python', 'facerecognition-general', 'multinomialnb-general','passiveaggressiveclassifier-general', 'perceptron-general', 'randomforestregressor-general', 'sgdclassifier-general', 'sgdregressor-general', 'svr-general']
for i in action_names:
    os.system(cmd.format(function=i))
# for i in action_names:
#     os.system(cmd_deleteHPA.format(function=i))
# for i in action_names:
#     os.system(cmd_changeCpu.format(function=i))
# for i in action_names:
#     os.system(cmd_watch.format(function=i))
# Out:
# horizontalpodautoscaler.autoscaling/hello-python autoscaled
# horizontalpodautoscaler.autoscaling/hash-python autoscaled
# horizontalpodautoscaler.autoscaling/cryptography-python autoscaled
# horizontalpodautoscaler.autoscaling/md5-python autoscaled
# horizontalpodautoscaler.autoscaling/sort-python autoscaled
# horizontalpodautoscaler.autoscaling/facerecognition-general autoscaled
# horizontalpodautoscaler.autoscaling/multinomialnb-general autoscaled
# horizontalpodautoscaler.autoscaling/passiveaggressiveclassifier-general autoscaled
# horizontalpodautoscaler.autoscaling/perceptron-general autoscaled
# horizontalpodautoscaler.autoscaling/randomforestregressor-general autoscaled
# horizontalpodautoscaler.autoscaling/sgdclassifier-general autoscaled
# horizontalpodautoscaler.autoscaling/sgdregressor-general autoscaled
# horizontalpodautoscaler.autoscaling/svr-general autoscaled

# %%
for i in action_names:
    os.system(cmd_watch.format(function=i))
# Out:
# NAME           REFERENCE                 TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# hello-python   Deployment/hello-python   <unknown>/30%   1         30        0          9s
# NAME          REFERENCE                TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# hash-python   Deployment/hash-python   <unknown>/30%   1         30        0          9s
# NAME                  REFERENCE                        TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# cryptography-python   Deployment/cryptography-python   <unknown>/30%   1         30        0          10s
# NAME         REFERENCE               TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# md5-python   Deployment/md5-python   <unknown>/30%   1         30        0          10s
# NAME          REFERENCE                TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# sort-python   Deployment/sort-python   <unknown>/30%   1         30        0          10s
# NAME                      REFERENCE                            TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# facerecognition-general   Deployment/facerecognition-general   <unknown>/30%   1         30        0          9s
# NAME                    REFERENCE                          TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# multinomialnb-general   Deployment/multinomialnb-general   <unknown>/30%   1         30        0          9s
# NAME                                  REFERENCE                                        TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# passiveaggressiveclassifier-general   Deployment/passiveaggressiveclassifier-general   <unknown>/30%   1         30        0          9s
# NAME                 REFERENCE                       TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# perceptron-general   Deployment/perceptron-general   <unknown>/30%   1         30        0          9s
# NAME                            REFERENCE                                  TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# randomforestregressor-general   Deployment/randomforestregressor-general   <unknown>/30%   1         30        0          9s
# NAME                    REFERENCE                          TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# sgdclassifier-general   Deployment/sgdclassifier-general   <unknown>/30%   1         30        0          9s
# NAME                   REFERENCE                         TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# sgdregressor-general   Deployment/sgdregressor-general   <unknown>/30%   1         30        0          9s
# NAME          REFERENCE                TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# svr-general   Deployment/svr-general   <unknown>/30%   1         30        0          9s

# %%
print(time.time)
! hey -c 5 -z 5m http://serverless.siat.ac.cn:31112/function/hello-python.openfaas-fn
print(time.time)
# Out:
# <built-in function time>
#
# Summary:
#   Total:	300.1298 secs
#   Slowest:	0.3222 secs
#   Fastest:	0.0028 secs
#   Average:	0.1062 secs
#   Requests/sec:	47.0796
#
#   Total data:	1098751 bytes
#   Size/request:	77 bytes
#
# Response time histogram:
#   0.003 [1]	|
#   0.035 [3]	|
#   0.067 [52]	|
#   0.099 [2362]	|■■■■■■■■■
#   0.131 [11076]	|■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   0.162 [559]	|■■
#   0.194 [64]	|
#   0.226 [8]	|
#   0.258 [0]	|
#   0.290 [0]	|
#   0.322 [5]	|
#
#
# Latency distribution:
#   10% in 0.0966 secs
#   25% in 0.1012 secs
#   50% in 0.1054 secs
#   75% in 0.1092 secs
#   90% in 0.1158 secs
#   95% in 0.1285 secs
#   99% in 0.1552 secs
#
# Details (average, fastest, slowest):
#   DNS+dialup:	0.0000 secs, 0.0028 secs, 0.3222 secs
#   DNS-lookup:	0.0000 secs, 0.0000 secs, 0.0004 secs
#   req write:	0.0000 secs, 0.0000 secs, 0.0005 secs
#   resp wait:	0.1061 secs, 0.0027 secs, 0.3219 secs
#   resp read:	0.0001 secs, 0.0000 secs, 0.0022 secs
#
# Status code distribution:
#   [200]	14126 responses
#   [503]	4 responses
#
#
#
# <built-in function time>

# %%
print(time.time)
! hey -c 5 -z 20m http://serverless.siat.ac.cn:31112/function/stream.openfaas-fn
print(time.time)

# %%
print(time.time)
! hey -c 5 -z 5m http://serverless.siat.ac.cn:31112/function/facerecognition-general.openfaas-fn
print(time.time)
# Out:
# <built-in function time>
#
# Summary:
#   Total:	300.8901 secs
#   Slowest:	2.2221 secs
#   Fastest:	1.4459 secs
#   Average:	1.8228 secs
#   Requests/sec:	2.7419
#
#   Total data:	53413 bytes
#   Size/request:	64 bytes
#
# Response time histogram:
#   1.446 [1]	|
#   1.524 [4]	|■
#   1.601 [25]	|■■■■■
#   1.679 [76]	|■■■■■■■■■■■■■■
#   1.756 [148]	|■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   1.834 [219]	|■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   1.912 [166]	|■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
#   1.989 [92]	|■■■■■■■■■■■■■■■■■
#   2.067 [53]	|■■■■■■■■■■
#   2.144 [29]	|■■■■■
#   2.222 [12]	|■■
#
#
# Latency distribution:
#   10% in 1.6593 secs
#   25% in 1.7336 secs
#   50% in 1.8143 secs
#   75% in 1.9033 secs
#   90% in 2.0011 secs
#   95% in 2.0700 secs
#   99% in 2.1867 secs
#
# Details (average, fastest, slowest):
#   DNS+dialup:	0.0000 secs, 1.4459 secs, 2.2221 secs
#   DNS-lookup:	0.0000 secs, 0.0000 secs, 0.0005 secs
#   req write:	0.0000 secs, 0.0000 secs, 0.0001 secs
#   resp wait:	1.8226 secs, 1.4457 secs, 2.2219 secs
#   resp read:	0.0001 secs, 0.0000 secs, 0.0008 secs
#
# Status code distribution:
#   [200]	825 responses
#
#
#
# <built-in function time>
